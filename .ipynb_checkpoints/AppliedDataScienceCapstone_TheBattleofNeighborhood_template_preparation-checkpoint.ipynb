# %% [markdown]
# # Wk4-5 : The Battle of Neighborhood - template preparation

# %% [markdown]
# #### Importing libraries

# %%
import numpy as np 
import pandas as pd

import json

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

import folium # map rendering library

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab

# %% [markdown]
# # Results from the previous assignment and clean-up

# %% [markdown]
# ### Clean up of the data

# %% [markdown]
# Making a dataframe from the raw data of Postal Code data from Toronto's Wikipedia

# %%
df_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df_wiki.to_excel("df_wiki.xlsx")

# %% [markdown]
# Dropping the rows with "Not assigned" in Borough

# %%
df_wiki.drop(df_wiki[df_wiki['Borough']=='Not assigned'].index, axis=0, inplace=True)
df_wiki = df_wiki.reset_index(drop=True)
#df_wiki

# %% [markdown]
# #### Acquisition of geographical coordinates for each Postal Code

# %% [markdown]
# Read the csv file of geographical coordinates of each postal code

# %%
df_Geocsv = pd.read_csv('Geospatial_Coordinates.csv')
df_Geocsv = df_Geocsv.reset_index(drop=True)
#df_Geocsv

# %% [markdown]
# Merging wiki data and geographical coordinates data

# %%
df = df_wiki
df['Latitude']=""
df['Longitude']=""

# %%
for i in range(0,df.shape[0]):
    for k in range(0,df_Geocsv.shape[0]):
        if (df_Geocsv['Postal Code'][k] == df['Postal Code'][i]):
            df['Latitude'][i] = df_Geocsv['Latitude'][k]
            df['Longitude'][i] = df_Geocsv['Longitude'][k]
            k =+ 1

# %% [markdown]
# #### The dataframe with Borough, Neighborhood and geographical coordinates

# %%
df.drop(['Postal Code'], axis=1,inplace=True)
print(df.shape)
df.head()
# Out:
# (103, 4)
#             Borough                                 Neighborhood Latitude  \
# 0        North York                                    Parkwoods  43.7533
# 1        North York                             Victoria Village  43.7259
# 2  Downtown Toronto                    Regent Park, Harbourfront  43.6543
# 3        North York             Lawrence Manor, Lawrence Heights  43.7185
# 4  Downtown Toronto  Queen's Park, Ontario Provincial Government  43.6623
#
#   Longitude
# 0  -79.3297
# 1  -79.3156
# 2  -79.3606
# 3  -79.4648
# 4  -79.3895

# %% [markdown]
# ## 3. Exploring around Toronto

# %% [markdown]
# #### 1. Making the dataframe that contains "Toronto" in "Borough" cells

# %%
df['Borough'].unique()
# Out:
# array(['North York', 'Downtown Toronto', 'Etobicoke', 'Scarborough',
#        'East York', 'York', 'East Toronto', 'West Toronto',
#        'Central Toronto', 'Mississauga'], dtype=object)

# %%
df_trnt=df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)

# %%
df_trnt.head()
# Out:
#             Borough                                 Neighborhood Latitude  \
# 0  Downtown Toronto                    Regent Park, Harbourfront  43.6543
# 1  Downtown Toronto  Queen's Park, Ontario Provincial Government  43.6623
# 2  Downtown Toronto                     Garden District, Ryerson  43.6572
# 3  Downtown Toronto                               St. James Town  43.6515
# 4      East Toronto                                  The Beaches  43.6764
#
#   Longitude
# 0  -79.3606
# 1  -79.3895
# 2  -79.3789
# 3  -79.3754
# 4   -79.293

# %% [markdown]
# #### Longitude and latitude of Toronto

# %%
lat_trnt = 43.651070
lon_trnt = -79.347015

# %% [markdown]
# #### Create a map of Tpronto with neighborhoods superimposed on top

# %%
# create map of Toronto using latitude and longitude values
map_trnt = folium.Map(location=[lat_trnt, lon_trnt], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_trnt['Latitude'], df_trnt['Longitude'], df_trnt['Borough'], df_trnt['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#2233cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_trnt)
    
map_trnt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'TKC5I1TJWMRGIADZYG14FAZWYPD1IGKNZ5EWK4PTQJUSACLS' # your Foursquare ID
CLIENT_SECRET = 'N2LTPZHIYBAGUR1PGDUSLREYTE1OXCL2HZBJLVSZ3BFFJSWE' # your Foursquare Secret
VERSION = '20200625'
LIMIT = 30 #Original Limit
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TKC5I1TJWMRGIADZYG14FAZWYPD1IGKNZ5EWK4PTQJUSACLS
# CLIENT_SECRET:N2LTPZHIYBAGUR1PGDUSLREYTE1OXCL2HZBJLVSZ3BFFJSWE

# %% [markdown]
# #### Function to repeat acquiring the nearby venues for all neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_trnt['Neighborhood'],
                                   latitudes=df_trnt['Latitude'],
                                   longitudes=df_trnt['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %% [markdown]
# #### Check the size of acquired dataframe

# %%
toronto_venues.shape
# Out:
# (866, 7)

# %%
toronto_venues.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                       Venue  Venue Latitude  Venue Longitude  \
# 0          Roselle Desserts       43.653447       -79.362017
# 1             Tandem Coffee       43.653559       -79.361809
# 2    Cooper Koo Family YMCA       43.653249       -79.358008
# 3       Body Blitz Spa East       43.654735       -79.359874
# 4  Dominion Pub and Kitchen       43.656919       -79.358967
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4                  Pub

# %% [markdown]
# #### Show how many venues are returned

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            30
# Brockton, Parkdale Village, Exhibition Place                           24
# Business reply mail Processing Centre, South Ce...                     17
# CN Tower, King and Spadina, Railway Lands, Harb...                     17
# Central Bay Street                                                     30
# Christie                                                               16
# Church and Wellesley                                                   30
# Commerce Court, Victoria Hotel                                         30
# Davisville                                                             30
# Davisville North                                                        8
# Dufferin, Dovercourt Village                                           14
# First Canadian Place, Underground city                                 30
# Forest Hill North & West, Forest Hill Road Park                         4
# Garden District, Ryerson                                               30
# Harbourfront East, Union Station, Toronto Islands                      30
# High Park, The Junction South                                          24
# India Bazaar, The Beaches West                                         24
# Kensington Market, Chinatown, Grange Park                              30
# Lawrence Park                                                           3
# Little Portugal, Trinity                                               30
# Moore Park, Summerhill East                                             2
# North Toronto West, Lawrence Park                                      19
# Parkdale, Roncesvalles                                                 15
# Queen's Park, Ontario Provincial Government                            30
# Regent Park, Harbourfront                                              30
# Richmond, Adelaide, King                                               30
# Rosedale                                                                4
# Roselawn                                                                2
# Runnymede, Swansea                                                     30
# St. James Town                                                         30
# St. James Town, Cabbagetown                                            30
# Stn A PO Boxes                                                         30
# Studio District                                                        30
# Summerhill West, Rathnelly, South Hill, Forest ...                     16
# The Annex, North Midtown, Yorkville                                    23
# The Beaches                                                             4
# The Danforth West, Riverdale                                           30
# Toronto Dominion Centre, Design Exchange                               30
# University of Toronto, Harbord                                         30
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             30
# Brockton, Parkdale Village, Exhibition Place                            24
# Business reply mail Processing Centre, South Ce...                      17
# CN Tower, King and Spadina, Railway Lands, Harb...                      17
# Central Bay Street                                                      30
# Christie                                                                16
# Church and Wellesley                                                    30
# Commerce Court, Victoria Hotel                                          30
# Davisville                                                              30
# Davisville North                                                         8
# Dufferin, Dovercourt Village                                            14
# First Canadian Place, Underground city                                  30
# Forest Hill North & West, Forest Hill Road Park                          4
# Garden District, Ryerson                                                30
# Harbourfront East, Union Station, Toronto Islands                       30
# High Park, The Junction South                                           24
# India Bazaar, The Beaches West                                          24
# Kensington Market, Chinatown, Grange Park                               30
# Lawrence Park                                                            3
# Little Portugal, Trinity                                                30
# Moore Park, Summerhill East                                              2
# North Toronto West, Lawrence Park                                       19
# Parkdale, Roncesvalles                                                  15
# Queen's Park, Ontario Provincial Government                             30
# Regent Park, Harbourfront                                               30
# Richmond, Adelaide, King                                                30
# Rosedale                                                                 4
# Roselawn                                                                 2
# Runnymede, Swansea                                                      30
# St. James Town                                                          30
# St. James Town, Cabbagetown                                             30
# Stn A PO Boxes                                                          30
# Studio District                                                         30
# Summerhill West, Rathnelly, South Hill, Forest ...                      16
# The Annex, North Midtown, Yorkville                                     23
# The Beaches                                                              4
# The Danforth West, Riverdale                                            30
# Toronto Dominion Centre, Design Exchange                                30
# University of Toronto, Harbord                                          30
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            30              30
# Brockton, Parkdale Village, Exhibition Place           24              24
# Business reply mail Processing Centre, South Ce...     17              17
# CN Tower, King and Spadina, Railway Lands, Harb...     17              17
# Central Bay Street                                     30              30
# Christie                                               16              16
# Church and Wellesley                                   30              30
# Commerce Court, Victoria Hotel                         30              30
# Davisville                                             30              30
# Davisville North                                        8               8
# Dufferin, Dovercourt Village                           14              14
# First Canadian Place, Underground city                 30              30
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                               30              30
# Harbourfront East, Union Station, Toronto Islands      30              30
# High Park, The Junction South                          24              24
# India Bazaar, The Beaches West                         24              24
# Kensington Market, Chinatown, Grange Park              30              30
# Lawrence Park                                           3               3
# Little Portugal, Trinity                               30              30
# Moore Park, Summerhill East                             2               2
# North Toronto West, Lawrence Park                      19              19
# Parkdale, Roncesvalles                                 15              15
# Queen's Park, Ontario Provincial Government            30              30
# Regent Park, Harbourfront                              30              30
# Richmond, Adelaide, King                               30              30
# Rosedale                                                4               4
# Roselawn                                                2               2
# Runnymede, Swansea                                     30              30
# St. James Town                                         30              30
# St. James Town, Cabbagetown                            30              30
# Stn A PO Boxes                                         30              30
# Studio District                                        30              30
# Summerhill West, Rathnelly, South Hill, Forest ...     16              16
# The Annex, North Midtown, Yorkville                    23              23
# The Beaches                                             4               4
# The Danforth West, Riverdale                           30              30
# Toronto Dominion Centre, Design Exchange               30              30
# University of Toronto, Harbord                         30              30
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      30
# Brockton, Parkdale Village, Exhibition Place                     24
# Business reply mail Processing Centre, South Ce...               17
# CN Tower, King and Spadina, Railway Lands, Harb...               17
# Central Bay Street                                               30
# Christie                                                         16
# Church and Wellesley                                             30
# Commerce Court, Victoria Hotel                                   30
# Davisville                                                       30
# Davisville North                                                  8
# Dufferin, Dovercourt Village                                     14
# First Canadian Place, Underground city                           30
# Forest Hill North & West, Forest Hill Road Park                   4
# Garden District, Ryerson                                         30
# Harbourfront East, Union Station, Toronto Islands                30
# High Park, The Junction South                                    24
# India Bazaar, The Beaches West                                   24
# Kensington Market, Chinatown, Grange Park                        30
# Lawrence Park                                                     3
# Little Portugal, Trinity                                         30
# Moore Park, Summerhill East                                       2
# North Toronto West, Lawrence Park                                19
# Parkdale, Roncesvalles                                           15
# Queen's Park, Ontario Provincial Government                      30
# Regent Park, Harbourfront                                        30
# Richmond, Adelaide, King                                         30
# Rosedale                                                          4
# Roselawn                                                          2
# Runnymede, Swansea                                               30
# St. James Town                                                   30
# St. James Town, Cabbagetown                                      30
# Stn A PO Boxes                                                   30
# Studio District                                                  30
# Summerhill West, Rathnelly, South Hill, Forest ...               16
# The Annex, North Midtown, Yorkville                              23
# The Beaches                                                       4
# The Danforth West, Riverdale                                     30
# Toronto Dominion Centre, Design Exchange                         30
# University of Toronto, Harbord                                   30
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     30
# Brockton, Parkdale Village, Exhibition Place                    24
# Business reply mail Processing Centre, South Ce...              17
# CN Tower, King and Spadina, Railway Lands, Harb...              17
# Central Bay Street                                              30
# Christie                                                        16
# Church and Wellesley                                            30
# Commerce Court, Victoria Hotel                                  30
# Davisville                                                      30
# Davisville North                                                 8
# Dufferin, Dovercourt Village                                    14
# First Canadian Place, Underground city                          30
# Forest Hill North & West, Forest Hill Road Park                  4
# Garden District, Ryerson                                        30
# Harbourfront East, Union Station, Toronto Islands               30
# High Park, The Junction South                                   24
# India Bazaar, The Beaches West                                  24
# Kensington Market, Chinatown, Grange Park                       30
# Lawrence Park                                                    3
# Little Portugal, Trinity                                        30
# Moore Park, Summerhill East                                      2
# North Toronto West, Lawrence Park                               19
# Parkdale, Roncesvalles                                          15
# Queen's Park, Ontario Provincial Government                     30
# Regent Park, Harbourfront                                       30
# Richmond, Adelaide, King                                        30
# Rosedale                                                         4
# Roselawn                                                         2
# Runnymede, Swansea                                              30
# St. James Town                                                  30
# St. James Town, Cabbagetown                                     30
# Stn A PO Boxes                                                  30
# Studio District                                                 30
# Summerhill West, Rathnelly, South Hill, Forest ...              16
# The Annex, North Midtown, Yorkville                             23
# The Beaches                                                      4
# The Danforth West, Riverdale                                    30
# Toronto Dominion Centre, Design Exchange                        30
# University of Toronto, Harbord                                  30

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 195 uniques categories.

# %% [markdown]
# ### Analyize each Neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

#toronto_onehot.head()

# %% [markdown]
# #### Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
#toronto_grouped

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                 venue  freq
# 0        Cocktail Bar  0.07
# 1         Coffee Shop  0.07
# 2            Beer Bar  0.07
# 3  Seafood Restaurant  0.07
# 4         Fish Market  0.03
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                     venue  freq
# 0                    Café  0.12
# 1                  Bakery  0.08
# 2          Breakfast Spot  0.08
# 3             Coffee Shop  0.08
# 4  Furniture / Home Store  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                 venue  freq
# 0         Yoga Studio  0.06
# 1             Brewery  0.06
# 2       Garden Center  0.06
# 3              Garden  0.06
# 4  Light Rail Station  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0   Airport Service  0.18
# 1    Airport Lounge  0.12
# 2  Airport Terminal  0.12
# 3          Boutique  0.06
# 4     Boat or Ferry  0.06
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.20
# 1   Italian Restaurant  0.07
# 2                 Café  0.07
# 3  Japanese Restaurant  0.07
# 4      Bubble Tea Shop  0.03
#
#
# ----Christie----
#            venue  freq
# 0  Grocery Store  0.25
# 1           Café  0.19
# 2           Park  0.12
# 3          Diner  0.06
# 4    Candy Store  0.06
#
#
# ----Church and Wellesley----
#                 venue  freq
# 0             Gay Bar  0.07
# 1           Wine Shop  0.03
# 2  Mexican Restaurant  0.03
# 3      Breakfast Spot  0.03
# 4     Bubble Tea Shop  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#          venue  freq
# 0         Café  0.17
# 1  Coffee Shop  0.10
# 2   Restaurant  0.07
# 3        Hotel  0.07
# 4     Tea Room  0.03
#
#
# ----Davisville----
#             venue  freq
# 0    Dessert Shop  0.10
# 1             Gym  0.07
# 2  Sandwich Place  0.07
# 3            Café  0.07
# 4     Coffee Shop  0.07
#
#
# ----Davisville North----
#                venue  freq
# 0                Gym  0.12
# 1              Hotel  0.12
# 2     Breakfast Spot  0.12
# 3            Dog Run  0.12
# 4  Food & Drink Shop  0.12
#
#
# ----Dufferin, Dovercourt Village----
#            venue  freq
# 0       Pharmacy  0.14
# 1         Bakery  0.14
# 2  Grocery Store  0.07
# 3    Music Venue  0.07
# 4    Supermarket  0.07
#
#
# ----First Canadian Place, Underground city----
#                 venue  freq
# 0                Café  0.13
# 1         Coffee Shop  0.10
# 2          Restaurant  0.10
# 3            Tea Room  0.07
# 4  Seafood Restaurant  0.07
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#               venue  freq
# 0              Park  0.25
# 1     Jewelry Store  0.25
# 2             Trail  0.25
# 3  Sushi Restaurant  0.25
# 4       Yoga Studio  0.00
#
#
# ----Garden District, Ryerson----
#             venue  freq
# 0            Café  0.10
# 1  Clothing Store  0.07
# 2         Theater  0.07
# 3     Coffee Shop  0.07
# 4           Plaza  0.03
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#          venue  freq
# 0        Plaza  0.07
# 1        Hotel  0.07
# 2         Café  0.07
# 3         Park  0.07
# 4  Supermarket  0.03
#
#
# ----High Park, The Junction South----
#                  venue  freq
# 0                 Café  0.08
# 1   Mexican Restaurant  0.08
# 2      Thai Restaurant  0.08
# 3          Flea Market  0.04
# 4  Arts & Crafts Store  0.04
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0                  Park  0.08
# 1           Pizza Place  0.08
# 2  Fast Food Restaurant  0.08
# 3        Sandwich Place  0.08
# 4             Pet Store  0.04
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0                           Café  0.10
# 1                         Bakery  0.07
# 2             Mexican Restaurant  0.07
# 3          Vietnamese Restaurant  0.07
# 4  Vegetarian / Vegan Restaurant  0.07
#
#
# ----Lawrence Park----
#                         venue  freq
# 0                        Park  0.33
# 1                 Swim School  0.33
# 2                    Bus Line  0.33
# 3                 Yoga Studio  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                    venue  freq
# 0                    Bar  0.10
# 1  Vietnamese Restaurant  0.07
# 2       Asian Restaurant  0.07
# 3            Men's Store  0.07
# 4            Yoga Studio  0.03
#
#
# ----Moore Park, Summerhill East----
#                  venue  freq
# 0                  Gym   0.5
# 1                Trail   0.5
# 2          Yoga Studio   0.0
# 3  Monument / Landmark   0.0
# 4   Mac & Cheese Joint   0.0
#
#
# ----North Toronto West, Lawrence Park----
#                   venue  freq
# 0           Coffee Shop  0.11
# 1        Clothing Store  0.11
# 2           Yoga Studio  0.05
# 3   Sporting Goods Shop  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.13
# 1                    Gift Shop  0.13
# 2                    Bookstore  0.07
# 3  Eastern European Restaurant  0.07
# 4                Movie Theater  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                 venue  freq
# 0         Coffee Shop  0.20
# 1               Diner  0.07
# 2    Sushi Restaurant  0.07
# 3         Yoga Studio  0.03
# 4  Mexican Restaurant  0.03
#
#
# ----Regent Park, Harbourfront----
#             venue  freq
# 0     Coffee Shop  0.20
# 1            Park  0.10
# 2         Theater  0.07
# 3  Breakfast Spot  0.07
# 4            Café  0.07
#
#
# ----Richmond, Adelaide, King----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1                  Café  0.10
# 2           Pizza Place  0.07
# 3  Gym / Fitness Center  0.03
# 4    Seafood Restaurant  0.03
#
#
# ----Rosedale----
#                         venue  freq
# 0                        Park  0.50
# 1                  Playground  0.25
# 2                       Trail  0.25
# 3                 Yoga Studio  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Roselawn----
#                  venue  freq
# 0               Garden   0.5
# 1          Music Venue   0.5
# 2          Yoga Studio   0.0
# 3  Monument / Landmark   0.0
# 4   Mac & Cheese Joint   0.0
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0    Sushi Restaurant  0.10
# 1         Coffee Shop  0.10
# 2                Café  0.10
# 3         Pizza Place  0.07
# 4  Italian Restaurant  0.07
#
#
# ----St. James Town----
#                  venue  freq
# 0            Gastropub  0.10
# 1  Japanese Restaurant  0.07
# 2           Restaurant  0.07
# 3          Coffee Shop  0.07
# 4                 Café  0.07
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0              Bakery  0.07
# 1  Italian Restaurant  0.07
# 2          Restaurant  0.07
# 3         Coffee Shop  0.07
# 4                Café  0.07
#
#
# ----Stn A PO Boxes----
#           venue  freq
# 0    Restaurant  0.07
# 1  Cocktail Bar  0.07
# 2          Café  0.07
# 3      Beer Bar  0.07
# 4  Concert Hall  0.03
#
#
# ----Studio District----
#          venue  freq
# 0         Café  0.13
# 1  Coffee Shop  0.10
# 2       Bakery  0.07
# 3  Yoga Studio  0.03
# 4         Park  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                  Pub  0.12
# 2     Sushi Restaurant  0.06
# 3  Fried Chicken Joint  0.06
# 4           Bagel Shop  0.06
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0     Coffee Shop  0.13
# 1            Café  0.13
# 2  Sandwich Place  0.13
# 3   Grocery Store  0.04
# 4       BBQ Joint  0.04
#
#
# ----The Beaches----
#                  venue  freq
# 0    Health Food Store  0.25
# 1                Trail  0.25
# 2                  Pub  0.25
# 3          Yoga Studio  0.00
# 4  Monument / Landmark  0.00
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.20
# 1  Italian Restaurant  0.10
# 2      Ice Cream Shop  0.07
# 3          Restaurant  0.07
# 4         Yoga Studio  0.03
#
#
# ----Toronto Dominion Centre, Design Exchange----
#             venue  freq
# 0            Café  0.20
# 1     Coffee Shop  0.17
# 2      Restaurant  0.07
# 3        Tea Room  0.03
# 4  Sandwich Place  0.03
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.13
# 1  Japanese Restaurant  0.07
# 2            Bookstore  0.07
# 3           Restaurant  0.07
# 4                  Bar  0.07

# %% [markdown]
# #### Function to sort the venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# #### Create the new dataframe with the topc 10 venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

#neighborhoods_venues_sorted

# %%
neighborhoods_venues_sorted.shape
# Out:
# (39, 11)

# %% [markdown]
# ### Cluster Neighborhoods

# %% [markdown]
# #### Run k-means to cluster the neighborhood into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 0, 1, 1, 0, 0, 1, 0, 0, 1], dtype=int32)

# %% [markdown]
# #### Creat a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_data_merged = df_trnt

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_data_merged = toronto_data_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_data_merged
# Out:
#              Borough                                       Neighborhood  \
# 0   Downtown Toronto                          Regent Park, Harbourfront
# 1   Downtown Toronto        Queen's Park, Ontario Provincial Government
# 2   Downtown Toronto                           Garden District, Ryerson
# 3   Downtown Toronto                                     St. James Town
# 4       East Toronto                                        The Beaches
# 5   Downtown Toronto                                        Berczy Park
# 6   Downtown Toronto                                 Central Bay Street
# 7   Downtown Toronto                                           Christie
# 8   Downtown Toronto                           Richmond, Adelaide, King
# 9       West Toronto                       Dufferin, Dovercourt Village
# 10  Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 11      West Toronto                           Little Portugal, Trinity
# 12      East Toronto                       The Danforth West, Riverdale
# 13  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 14      West Toronto       Brockton, Parkdale Village, Exhibition Place
# 15      East Toronto                     India Bazaar, The Beaches West
# 16  Downtown Toronto                     Commerce Court, Victoria Hotel
# 17      East Toronto                                    Studio District
# 18   Central Toronto                                      Lawrence Park
# 19   Central Toronto                                           Roselawn
# 20   Central Toronto                                   Davisville North
# 21   Central Toronto    Forest Hill North & West, Forest Hill Road Park
# 22      West Toronto                      High Park, The Junction South
# 23   Central Toronto                  North Toronto West, Lawrence Park
# 24   Central Toronto                The Annex, North Midtown, Yorkville
# 25      West Toronto                             Parkdale, Roncesvalles
# 26   Central Toronto                                         Davisville
# 27  Downtown Toronto                     University of Toronto, Harbord
# 28      West Toronto                                 Runnymede, Swansea
# 29   Central Toronto                        Moore Park, Summerhill East
# 30  Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 31   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 32  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
# 33  Downtown Toronto                                           Rosedale
# 34  Downtown Toronto                                     Stn A PO Boxes
# 35  Downtown Toronto                        St. James Town, Cabbagetown
# 36  Downtown Toronto             First Canadian Place, Underground city
# 37  Downtown Toronto                               Church and Wellesley
# 38      East Toronto  Business reply mail Processing Centre, South C...
#
#    Latitude Longitude  Cluster Labels 1st Most Common Venue  \
# 0   43.6543  -79.3606               0           Coffee Shop
# 1   43.6623  -79.3895               0           Coffee Shop
# 2   43.6572  -79.3789               0                  Café
# 3   43.6515  -79.3754               0             Gastropub
# 4   43.6764   -79.293               1                 Trail
# 5   43.6448  -79.3733               1           Coffee Shop
# 6    43.658  -79.3874               0           Coffee Shop
# 7   43.6695  -79.4226               0         Grocery Store
# 8   43.6506  -79.3846               0           Coffee Shop
# 9    43.669  -79.4423               1              Pharmacy
# 10  43.6408  -79.3818               1                 Plaza
# 11  43.6479  -79.4197               1                   Bar
# 12  43.6796  -79.3522               1      Greek Restaurant
# 13  43.6472  -79.3816               0                  Café
# 14  43.6368  -79.4282               0                  Café
# 15   43.669  -79.3156               1        Sandwich Place
# 16  43.6482  -79.3798               0                  Café
# 17  43.6595  -79.3409               0                  Café
# 18   43.728  -79.3888               1                  Park
# 19  43.7117  -79.4169               4                Garden
# 20  43.7128  -79.3902               1                 Hotel
# 21  43.6969  -79.4113               3                  Park
# 22  43.6616  -79.4648               1                  Café
# 23  43.7154  -79.4057               0           Coffee Shop
# 24  43.6727  -79.4057               0           Coffee Shop
# 25   43.649  -79.4563               1             Gift Shop
# 26  43.7043  -79.3888               0          Dessert Shop
# 27  43.6627     -79.4               1                  Café
# 28  43.6516  -79.4844               0      Sushi Restaurant
# 29  43.6896  -79.3832               2                   Gym
# 30  43.6532     -79.4               1                  Café
# 31  43.6864     -79.4               0           Coffee Shop
# 32  43.6289  -79.3944               1       Airport Service
# 33  43.6796  -79.3775               3                  Park
# 34  43.6464  -79.3748               1            Restaurant
# 35   43.668  -79.3677               0           Coffee Shop
# 36  43.6484  -79.3823               0                  Café
# 37  43.6659  -79.3832               1               Gay Bar
# 38  43.6627  -79.3216               1           Yoga Studio
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0                            Park               Theater
# 1                Sushi Restaurant                 Diner
# 2                  Clothing Store               Theater
# 3             Japanese Restaurant                  Café
# 4               Health Food Store                   Pub
# 5                    Cocktail Bar              Beer Bar
# 6              Italian Restaurant                  Café
# 7                            Café                  Park
# 8                            Café           Pizza Place
# 9                          Bakery           Supermarket
# 10                           Café                 Hotel
# 11          Vietnamese Restaurant      Asian Restaurant
# 12             Italian Restaurant            Restaurant
# 13                    Coffee Shop            Restaurant
# 14                 Breakfast Spot                Bakery
# 15                           Park           Pizza Place
# 16                    Coffee Shop            Restaurant
# 17                    Coffee Shop                Bakery
# 18                    Swim School              Bus Line
# 19                    Music Venue             Wine Shop
# 20              Food & Drink Shop                  Park
# 21                  Jewelry Store                 Trail
# 22                Thai Restaurant    Mexican Restaurant
# 23                 Clothing Store           Yoga Studio
# 24                           Café        Sandwich Place
# 25                 Breakfast Spot                  Bank
# 26                    Coffee Shop      Sushi Restaurant
# 27            Japanese Restaurant            Restaurant
# 28                    Coffee Shop                  Café
# 29                          Trail             Wine Shop
# 30  Vegetarian / Vegan Restaurant    Mexican Restaurant
# 31                            Pub           Pizza Place
# 32                 Airport Lounge      Airport Terminal
# 33                     Playground                 Trail
# 34                   Cocktail Bar                  Café
# 35                         Bakery            Restaurant
# 36                     Restaurant           Coffee Shop
# 37                      Wine Shop     Indian Restaurant
# 38                    Pizza Place               Brewery
#
#     4th Most Common Venue        5th Most Common Venue  \
# 0          Breakfast Spot                         Café
# 1                     Bar                Smoothie Shop
# 2             Coffee Shop                   Steakhouse
# 3             Coffee Shop                   Restaurant
# 4               Wine Shop                     Creperie
# 5      Seafood Restaurant                         Park
# 6     Japanese Restaurant                        Hotel
# 7              Baby Store                    Nightclub
# 8      Seafood Restaurant         Gym / Fitness Center
# 9   Portuguese Restaurant                  Music Venue
# 10                   Park           Italian Restaurant
# 11            Men's Store                  Yoga Studio
# 12         Ice Cream Shop                  Yoga Studio
# 13            Pizza Place                  Art Gallery
# 14            Coffee Shop                    Pet Store
# 15   Fast Food Restaurant            Fish & Chips Shop
# 16                  Hotel       Gluten-free Restaurant
# 17            Yoga Studio      Comfort Food Restaurant
# 18       Cuban Restaurant                      Dog Run
# 19               Creperie                      Dog Run
# 20         Breakfast Spot               Sandwich Place
# 21       Sushi Restaurant                    Wine Shop
# 22              Gastropub          Arts & Crafts Store
# 23    Sporting Goods Shop                Grocery Store
# 24         History Museum                     Pharmacy
# 25     Italian Restaurant  Eastern European Restaurant
# 26            Pizza Place                         Café
# 27              Bookstore           Italian Restaurant
# 28            Pizza Place           Italian Restaurant
# 29       Cuban Restaurant                   Donut Shop
# 30                 Bakery        Vietnamese Restaurant
# 31             Restaurant           Light Rail Station
# 32          Boat or Ferry                  Coffee Shop
# 33        Coworking Space          Distribution Center
# 34               Beer Bar                 Concert Hall
# 35     Italian Restaurant                         Café
# 36     Seafood Restaurant                     Tea Room
# 37           Dance Studio                   Hobby Shop
# 38             Skate Park                Burrito Place
#
#         6th Most Common Venue      7th Most Common Venue  \
# 0                         Pub                     Bakery
# 1                    Beer Bar             Sandwich Place
# 2                  Comic Shop                      Hotel
# 3              Farmers Market             Ice Cream Shop
# 4                     Dog Run        Distribution Center
# 5              Breakfast Spot             Farmers Market
# 6                  Poke Place           Ramen Restaurant
# 7                 Candy Store                 Restaurant
# 8                   Juice Bar        Monument / Landmark
# 9                        Park                    Brewery
# 10               Dessert Shop                       Lake
# 11           Malay Restaurant                    Brewery
# 12                Pizza Place                  Bookstore
# 13              Deli / Bodega                   Beer Bar
# 14                 Restaurant               Intersection
# 15                    Brewery                 Restaurant
# 16       Gym / Fitness Center              Deli / Bodega
# 17                  Bookstore             Sandwich Place
# 18        Distribution Center             Discount Store
# 19        Distribution Center             Discount Store
# 20           Department Store                    Dog Run
# 21           Cuban Restaurant                    Dog Run
# 22                      Diner                  Bookstore
# 23       Fast Food Restaurant                      Diner
# 24                Pizza Place  Middle Eastern Restaurant
# 25                    Dog Run               Dessert Shop
# 26             Sandwich Place         Italian Restaurant
# 27                        Bar                     Bakery
# 28  Latin American Restaurant               Dessert Shop
# 29                    Dog Run        Distribution Center
# 30            Organic Grocery                Coffee Shop
# 31               Liquor Store                       Bank
# 32                   Boutique        Rental Car Location
# 33             Discount Store                      Diner
# 34             Breakfast Spot           Department Store
# 35                      Diner                  Pet Store
# 36       Gym / Fitness Center        Japanese Restaurant
# 37                       Café             Ice Cream Shop
# 38                 Restaurant           Recording Studio
#
#         8th Most Common Venue  9th Most Common Venue   10th Most Common Venue
# 0                  Restaurant         Chocolate Shop              Yoga Studio
# 1         Distribution Center         Discount Store              Yoga Studio
# 2           Electronics Store    Sporting Goods Shop            Shopping Mall
# 3          Italian Restaurant                  Hotel                BBQ Joint
# 4              Discount Store                  Diner             Dessert Shop
# 5          Basketball Stadium                 Museum                Jazz Club
# 6                  Steakhouse        Bubble Tea Shop         Sushi Restaurant
# 7                       Diner     Italian Restaurant              Coffee Shop
# 8                       Hotel                    Bar               Smoke Shop
# 9               Grocery Store                   Café                     Bank
# 10               Skating Rink        Bubble Tea Shop      Japanese Restaurant
# 11                Record Shop            Pizza Place              Coffee Shop
# 12                  Juice Bar           Dessert Shop                      Spa
# 13                 Steakhouse                    Pub     Gym / Fitness Center
# 14                    Stadium     Italian Restaurant        Convenience Store
# 15         Light Rail Station          Burrito Place       Italian Restaurant
# 16                        Pub    Japanese Restaurant                Bookstore
# 17                    Brewery            Cheese Shop                Pet Store
# 18                      Diner           Dessert Shop         Department Store
# 19                      Diner           Dessert Shop         Department Store
# 20                        Gym             Comic Shop  Comfort Food Restaurant
# 21        Distribution Center         Discount Store                    Diner
# 22  Cajun / Creole Restaurant     Italian Restaurant     Fast Food Restaurant
# 23         Mexican Restaurant              Pet Store       Chinese Restaurant
# 24                        Pub           Burger Joint             Liquor Store
# 25           Cuban Restaurant          Movie Theater               Restaurant
# 26                        Gym                   Park                 Pharmacy
# 27           Sushi Restaurant  College Arts Building             Noodle House
# 28              Burrito Place      Fish & Chips Shop      Indie Movie Theater
# 29             Discount Store                  Diner             Dessert Shop
# 30                Cheese Shop   Caribbean Restaurant              Fish Market
# 31                 Bagel Shop             Sports Bar              Supermarket
# 32            Harbor / Marina                  Plane         Sculpture Garden
# 33               Dessert Shop       Department Store            Deli / Bodega
# 34         Seafood Restaurant              Jazz Club                   Museum
# 35                        Pub          Deli / Bodega             Liquor Store
# 36                  Bookstore         Sandwich Place                      Pub
# 37                 Smoke Shop               Beer Bar                Juice Bar
# 38                    Butcher         Farmers Market     Fast Food Restaurant

# %%
# create map
map_clusters = folium.Map(location=[lat_trnt, lon_trnt], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_data_merged['Latitude'], toronto_data_merged['Longitude'], toronto_data_merged['Neighborhood'], toronto_data_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examin Clusters

# %%
toronto_data_merged.loc[toronto_data_merged['Cluster Labels'] == 0, toronto_data_merged.columns[[1] + list(range(5, toronto_data_merged.shape[1]))]]
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                           Regent Park, Harbourfront           Coffee Shop
# 1         Queen's Park, Ontario Provincial Government           Coffee Shop
# 2                            Garden District, Ryerson                  Café
# 3                                      St. James Town             Gastropub
# 6                                  Central Bay Street           Coffee Shop
# 7                                            Christie         Grocery Store
# 8                            Richmond, Adelaide, King           Coffee Shop
# 13           Toronto Dominion Centre, Design Exchange                  Café
# 14       Brockton, Parkdale Village, Exhibition Place                  Café
# 16                     Commerce Court, Victoria Hotel                  Café
# 17                                    Studio District                  Café
# 23                  North Toronto West, Lawrence Park           Coffee Shop
# 24                The Annex, North Midtown, Yorkville           Coffee Shop
# 26                                         Davisville          Dessert Shop
# 28                                 Runnymede, Swansea      Sushi Restaurant
# 31  Summerhill West, Rathnelly, South Hill, Forest...           Coffee Shop
# 35                        St. James Town, Cabbagetown           Coffee Shop
# 36             First Canadian Place, Underground city                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Park               Theater        Breakfast Spot
# 1       Sushi Restaurant                 Diner                   Bar
# 2         Clothing Store               Theater           Coffee Shop
# 3    Japanese Restaurant                  Café           Coffee Shop
# 6     Italian Restaurant                  Café   Japanese Restaurant
# 7                   Café                  Park            Baby Store
# 8                   Café           Pizza Place    Seafood Restaurant
# 13           Coffee Shop            Restaurant           Pizza Place
# 14        Breakfast Spot                Bakery           Coffee Shop
# 16           Coffee Shop            Restaurant                 Hotel
# 17           Coffee Shop                Bakery           Yoga Studio
# 23        Clothing Store           Yoga Studio   Sporting Goods Shop
# 24                  Café        Sandwich Place        History Museum
# 26           Coffee Shop      Sushi Restaurant           Pizza Place
# 28           Coffee Shop                  Café           Pizza Place
# 31                   Pub           Pizza Place            Restaurant
# 35                Bakery            Restaurant    Italian Restaurant
# 36            Restaurant           Coffee Shop    Seafood Restaurant
#
#       5th Most Common Venue      6th Most Common Venue  \
# 0                      Café                        Pub
# 1             Smoothie Shop                   Beer Bar
# 2                Steakhouse                 Comic Shop
# 3                Restaurant             Farmers Market
# 6                     Hotel                 Poke Place
# 7                 Nightclub                Candy Store
# 8      Gym / Fitness Center                  Juice Bar
# 13              Art Gallery              Deli / Bodega
# 14                Pet Store                 Restaurant
# 16   Gluten-free Restaurant       Gym / Fitness Center
# 17  Comfort Food Restaurant                  Bookstore
# 23            Grocery Store       Fast Food Restaurant
# 24                 Pharmacy                Pizza Place
# 26                     Café             Sandwich Place
# 28       Italian Restaurant  Latin American Restaurant
# 31       Light Rail Station               Liquor Store
# 35                     Café                      Diner
# 36                 Tea Room       Gym / Fitness Center
#
#         7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                      Bakery            Restaurant        Chocolate Shop
# 1              Sandwich Place   Distribution Center        Discount Store
# 2                       Hotel     Electronics Store   Sporting Goods Shop
# 3              Ice Cream Shop    Italian Restaurant                 Hotel
# 6            Ramen Restaurant            Steakhouse       Bubble Tea Shop
# 7                  Restaurant                 Diner    Italian Restaurant
# 8         Monument / Landmark                 Hotel                   Bar
# 13                   Beer Bar            Steakhouse                   Pub
# 14               Intersection               Stadium    Italian Restaurant
# 16              Deli / Bodega                   Pub   Japanese Restaurant
# 17             Sandwich Place               Brewery           Cheese Shop
# 23                      Diner    Mexican Restaurant             Pet Store
# 24  Middle Eastern Restaurant                   Pub          Burger Joint
# 26         Italian Restaurant                   Gym                  Park
# 28               Dessert Shop         Burrito Place     Fish & Chips Shop
# 31                       Bank            Bagel Shop            Sports Bar
# 35                  Pet Store                   Pub         Deli / Bodega
# 36        Japanese Restaurant             Bookstore        Sandwich Place
#
#    10th Most Common Venue
# 0             Yoga Studio
# 1             Yoga Studio
# 2           Shopping Mall
# 3               BBQ Joint
# 6        Sushi Restaurant
# 7             Coffee Shop
# 8              Smoke Shop
# 13   Gym / Fitness Center
# 14      Convenience Store
# 16              Bookstore
# 17              Pet Store
# 23     Chinese Restaurant
# 24           Liquor Store
# 26               Pharmacy
# 28    Indie Movie Theater
# 31            Supermarket
# 35           Liquor Store
# 36                    Pub
